# %%
from KTRtracker import ImageAnalyzer
# Out:
# Welcome to CellposeSAM, cellpose v
# cellpose version: 	4.0.6
# platform:       	win32
# python version: 	3.13.2
# torch version:  	2.7.1+cu126! The neural network component of
# CPSAM is much larger than in previous versions and CPU excution is slow.
# We encourage users to use GPU/MPS if available.

# %%
analyzer = ImageAnalyzer("20211126-test-image.tif")

# %%
analyzer.load_image()
# Out:
# Image shape: (60, 2, 298, 298)
# Timepoints: 60

# %%
analyzer.segment_nuclei()

# %%
analyzer.track_objects(min_track_length=60)
analyzer.convert_to_tracked_labels()

# %%
analyzer.generate_cytoplasmic_rings()

# %%
# Visualize results
intensity_df = analyzer.extract_intensity_features()
analyzer.visualize_cn_ratio(intensity_df)
analyzer.visualize_cn_ratio_timelapse(intensity_df, fps=20)
# Out:
# Static image saved to cn_ratio_timelapse_static.png
# Animation saved to cn_ratio_timelapse.gif
